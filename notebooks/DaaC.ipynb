# %% [markdown]
# Had to install graphviz on mac by running the command:
#
# brew install graphviz

# %%
# diagram.py
from diagrams import Diagram
from diagrams.aws.compute import EC2
from diagrams.aws.database import RDS
from diagrams.aws.network import ELB

with Diagram("Web Service", show=True, outformat="jpg") as diag :
    ELB("lb") >> EC2("web") >> RDS("userdb")
    
diag
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/graphviz/backend/execute.py:91, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      90 try:
# ---> 91     proc.check_returncode()
#      92 except subprocess.CalledProcessError as e:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:457, in CompletedProcess.check_returncode(self)
#     456 if self.returncode:
# --> 457     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     458                              self.stderr)
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tjpg', '-O', 'web_service']' died with <Signals.SIGKILL: 9>.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from diagrams import Diagram
from diagrams.aws.compute import EC2
from diagrams.aws.database import RDS
from diagrams.aws.network import ELB

with Diagram("Grouped Workers", show=False, direction="TB", filename="images/grouped_workers") as diag:
    ELB("lb") >> [EC2("worker1"),
                  EC2("worker2"),
                  EC2("worker3"),
                  EC2("worker4"),
                  EC2("worker5")] >> RDS("events")
    
diag
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/graphviz/backend/execute.py:91, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      90 try:
# ---> 91     proc.check_returncode()
#      92 except subprocess.CalledProcessError as e:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:457, in CompletedProcess.check_returncode(self)
#     456 if self.returncode:
# --> 457     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     458                              self.stderr)
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tpng', '-O', 'grouped_workers']' died with <Signals.SIGKILL: 9>.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# hello.py - http://www.graphviz.org/content/hello
from graphviz import Digraph

g = Digraph('G', filename='hello.gv')
g.edge('Hello', 'World')
g.view()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /opt/homebrew/Cellar/jupyterlab/3.4.8/libexec/lib/python3.10/site-packages/graphviz/backend/execute.py:91, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      90 try:
# ---> 91     proc.check_returncode()
#      92 except subprocess.CalledProcessError as e:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.8/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:457, in CompletedProcess.check_returncode(self)
#     456 if self.returncode:
# --> 457     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     458                              self.stderr)
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tpdf', '-O', 'hello.gv']' died with <Signals.SIGKILL: 9>.
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import torch
torch.manual_see(1234)

from torch.autograd import Variable
x=Variable(torch.ones(2,2) * 2, requires_grad=True)

z = 2 * (x * x) + 5 * x
z.backward(torch.ones(2,2))

print(x.grad)

from torch import make_dot

z

make_dot(z)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [25], line 1
# ----> 1 import torchviz
#       2 torchviz.manual_see(1234)
#       4 from torchviz.autograd import Variable
#
# ModuleNotFoundError: No module named 'torchviz'
